# %% [markdown]
# # SYSC4906 Assignment 3
#
# **Group Name:** Haseeb and Abraham
#
# **Student names:** Haseeb Khan, Abraham Srna
#
# **Student numbers:** 101009713, 100997482

# %% [markdown]
# # Code to Train Your Method
# _We will look at this, but will not run it when measuring your accuracy. Please structure your training code into logical steps, so that we can easily understand it_
# ## Step 1: Load the image dataset...

# %%
from keras.utils import to_categorical
from glob import glob
from keras.models import Model
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from PIL import Image
from google.colab import drive
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing import image as kp_image

# Constants
NEW_IMAGE_LENGTH = 500
NEW_IMAGE_HEIGHT = 500
CONTENT_DRIVE_PATH = '/content/drive'
PATH_TO_IMAGES = CONTENT_DRIVE_PATH + "/My Drive/All_Images"
BUILDING_CODES = ["AA", "CB", "CT", "DT", "FH", "HP", "HS", "LB",
                  "MC", "ME", "ML", "PA", "RB", "RO", "SA", "TB"]
TRAINING_SIZE = 0.1

# Use one hot encoding to encode all of the building codes
numericCodes = range(0, len(BUILDING_CODES))
oneHotEncodedCodes = to_categorical(numericCodes)

# Mount the Google Drive containing all of the images
drive.mount(CONTENT_DRIVE_PATH)

# Get the paths for all the training and testing data
xTrain = []
yTrain = []
xTest = []
yTest = []

# Loop through all of the folders
for i in range(len(BUILDING_CODES)):
  # Get the building code and one hot encoded version
  code = BUILDING_CODES[i]
  oneHotCode = oneHotEncodedCodes[i]

  # Get the paths
  paths = glob(PATH_TO_IMAGES + "/" + code + "/*.jpg")

  # Split the paths for testing and training to create the hold-out set
  train, test = train_test_split(paths, test_size = TRAINING_SIZE)

  # Add the data to the corresponding lists
  xTrain += train
  yTrain += [oneHotCode] * len(train)
  xTest += test
  yTest += [oneHotCode] * len(test)

def cropAndResize(imgPath, newLen=NEW_IMAGE_LENGTH, newHeight=NEW_IMAGE_HEIGHT):
  """
  cropAndResize

  Opens the image at the given path. If the image is a rectangle,
  it is cropped to turn it into a square. The cropped square is then
  resized to the given sizes.

  @input  imgPath   Path to the image to crop and resize
  @input  newLen    The new length for the image
  @input  newHeight The new height for the image

  @return A PIL image containing the cropped and resized image
          (None if the image cannot be opened)
  """

  # Open the image if possible
  try:
    im = Image.open(imgPath)
  except:
    print("Error: Could not open image: %s" % (imgPath))
    return None

  # Get the current size
  width, height = im.size

  # Set the default cropped dimensions (square)
  left = 0
  top = 0
  right = width
  bot = height

  # Check if the image is portrait or landscape and if so,
  # get the new cropped dimensions
  if width > height:
    diff = (width - height) / 2

    left = diff
    top = 0
    right = width - diff
    bot = height
  elif width < height:
    diff = (height - width) / 2

    left = 0
    top = diff
    right = width
    bot = height - diff

  # Crop and resize the image
  im1 = im.crop((left, top, right, bot))
  im1 = im1.resize((newLen, newHeight))

  return(im1)

def formatImageData(listOfImagePaths, labels):
  """
  formatImageData

  Wrapper for the cropAndResize method to handle lists
  of image paths. Crops and resizes each image,
  converting each one to a Numpy array. If the path is
  invalid, then the corresponding image and label is removed.
  Returns the final list of labels and the cropped and resized
  images in a numpy array.

  @input  listOfImagePaths  The list of image paths to resize and crop
  @input  labels            The current list of labels

  @returns The formatted images in a numpy array and the list of
           corresponding labels
  """
  retImgs = []
  retLabels = []

  # Loop through all of the image paths
  for i in range(len(listOfImagePaths)):
    path = listOfImagePaths[i]
    label = labels[i]

    print("Formatting Image: %s" % (path))
    
    # Format the image
    resizedImage = cropAndResize(path)
    if resizedImage != None:
      # Convert the image to a numpy array and save the label
      retImgs.append(np.array(resizedImage))
      retLabels.append(label)

  # Convert the return list as a numpy array
  retImgs = np.asarray(retImgs)

  return(retImgs, retLabels)

# Format all of the training and testing data
xTrain, yTrain = formatImageData(xTrain, yTrain)
xTest, yTest = formatImageData(xTest, yTest)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Formatting Image: /content/drive/My Drive/All_Images/AA/081_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/909-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/909-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/181_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/677-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/713_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/576_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/713_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/713_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/903-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/958-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/607_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/081_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/413_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/918-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/746_5.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/AA/746_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/607_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/909-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/880_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/142_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/713_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/367-3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/AA/367-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/157_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/285_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/958-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/542-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/918-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/443-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/677-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/181_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/367-4.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/AA/367-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/030_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/548_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/533_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/677-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/533_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/600-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/607_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/157_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/120-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/128-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/181_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/482-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/373-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/413_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/153_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/128-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/542-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/958-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/136-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/120-6.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/413_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/081_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/905_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/120-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/663_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/373-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/746_2.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/AA/746_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/606_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/918-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/959-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/837_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/905_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/548_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/219_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/443-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/959-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/182_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/837_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/548_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/607_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/182_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/880_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/576_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/909-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/482-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/837_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/219_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/367-1.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/AA/367-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/136-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/954-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/142_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/836_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/373-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/905_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/182_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/309-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/309-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/542-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/746_4.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/AA/746_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/958-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/713_6.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/746_3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/AA/746_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/030_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/250_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/533_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/959-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/250_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/413_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/285_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/120-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/954-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/576_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/606_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/880_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/964-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/142_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/120-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/964-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/373-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/600-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/576_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/959-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/600-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/746_1.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/AA/746_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/157_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/606_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/836_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/285_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/250_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/516_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/600-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/309-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/516_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/837_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/880_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/030_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/136-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/482-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/120-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/663_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/548_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/142_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/663_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/959-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/548_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/157_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/954-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/181_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/153_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/677-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/606_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/482-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/030_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/285_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/182_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/880_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/663_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/219_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/443-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/482-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/367-5.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/AA/367-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/713_7.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/903-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/964-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/250_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/153_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/903-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/516_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/153_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/157_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/081_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/182_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/081_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/136-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/954-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/542-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/128-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/663_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/128-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/030_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/443-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/181_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/954-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/533_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/713_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/516_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/836_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/542-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/606_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/905_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/964-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/909-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/373-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/836_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/837_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/964-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/309-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/219_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/533_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/607_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/AA/958-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/250_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/250_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/153_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/607_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/713_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/576_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/219_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/836_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/128-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/880_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/837_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/182_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/181_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/367-2.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CB/367-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/182_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/836_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/219_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/413_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/157_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/153_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/663_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/746_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/880_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/309-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/576_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/250_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/120-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/905_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/954-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/443-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/905_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/413_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/250_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/677-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/607_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/663_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/958-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/837_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/918-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/677-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/182_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/958-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/542-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/600-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/600-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/607_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/880_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/600-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/837_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/964-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/746_4.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CB/746_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/606_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/153_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/909-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/120-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/081_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/516_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/373-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/542-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/533_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/606_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/964-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/918-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/030_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/309-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/746_5.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CB/746_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/880_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/120-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/909-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/909-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/030_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/880_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/309-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/219_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/918-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/964-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/606_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/837_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/918-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/713_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/181_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/746_3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CB/746_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/120-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/367-4.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CB/367-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/600-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/954-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/285_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/142_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/250_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/img_20191119_140736.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/542-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/142_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/958-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/182_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/367-1.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CB/367-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/964-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/533_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/285_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/443-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/128-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/285_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/663_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/285_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/959-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/181_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/533_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/219_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/136-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/128-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/533_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/482-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/142_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/516_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/367-3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CB/367-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/373-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/373-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/663_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/548_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/413_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/309-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/548_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/954-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/413_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/958-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/905_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/153_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/836_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/548_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/903-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/606_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/516_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/677-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/142_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/607_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/548_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/600-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/157_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/909-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/909-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/136-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/959-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/903-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/081_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/607_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/903-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/903-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/516_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/136-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/954-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/713_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/542-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/677-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/030_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/959-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/153_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/181_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/443-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/142_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/157_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/128-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/443-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/482-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/713_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/918-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/373-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/157_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/959-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/542-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/030_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/285_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/030_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/373-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/663_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/959-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/533_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/958-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/836_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/157_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/905_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/548_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/954-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/img_20191119_140707.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/905_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/181_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/413_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/367-5.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CB/367-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/482-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/576_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/443-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/746_2.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CB/746_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CB/081_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/533_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/905_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/905_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/918-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/746_5.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CT/746_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/482-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/516_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/663_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/482-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/413_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/120-8.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/142_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/120-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/836_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/837_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/836_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/880_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/905_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/954-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/482-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/964-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/542-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/548_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/964-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/285_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/964-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/081_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/713_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/img_20191121_143521.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/746_3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CT/746_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/373-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/836_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/153_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/128-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/533_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/367-4.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CT/367-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/181_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/120-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/918-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/367-2.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CT/367-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/443-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/182_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/285_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/964-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/905_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/903-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/128-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/285_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/607_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/576_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/309-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/157_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/413_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/482-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/600-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/746_1.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CT/746_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/182_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/959-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/182_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/677-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/548_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/250_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/905_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/713_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/413_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/153_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/713_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/136-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/250_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/367-1.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CT/367-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/600-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/958-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/954-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/903-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/219_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/030_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/548_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/516_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/250_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/600-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/142_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/142_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/954-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/746_4.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CT/746_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/958-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/677-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/663_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/157_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/533_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/373-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/157_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/157_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/918-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/120-7.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/136-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/250_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/153_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/128-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/081_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/443-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/182_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/181_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/413_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/181_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/964-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/367-5.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CT/367-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/img_20191121_143543.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/954-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/958-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/182_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/880_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/128-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/836_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/677-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/606_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/309-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/120-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/181_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/909-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/081_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/606_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/120-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/120-6.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/606_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/219_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/903-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/142_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/181_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/443-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/482-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/576_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/909-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/285_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/128-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/837_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/954-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/373-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/746_2.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/CT/746_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/219_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/136-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/607_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/516_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/606_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/542-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/837_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/516_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/837_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/959-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/030_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/918-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/958-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/309-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/250_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/600-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/909-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/713_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/909-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/576_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/663_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/img_20191121_143231.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/607_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/136-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/958-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/880_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/903-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/959-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/903-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/030_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/309-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/081_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/542-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/837_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/713_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/285_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/663_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/576_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/120-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/542-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/959-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/142_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/548_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/219_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/606_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/157_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/309-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/030_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/516_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/836_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/880_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/153_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/548_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/219_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/413_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/CT/373-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/285_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/219_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/837_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/905_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/542-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/905_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/954-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/181_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/285_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/181_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/836_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/373-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/903-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/219_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/746_1.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/DT/746_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/081_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/413_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/903-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/954-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/182_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/285_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/964-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/677-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/954-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/746_5.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/DT/746_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/153_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/182_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/880_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/516_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/837_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/142_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/309-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/219_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/373-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/918-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/905_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/181_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/713_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/909-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/663_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/909-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/142_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/959-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/081_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/837_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/600-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/413_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/548_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/153_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/081_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/128-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/309-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/443-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/909-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/663_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/482-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/663_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/677-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/250_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/713_6.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/413_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/516_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/250_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/606_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/185_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/958-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/542-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/516_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/959-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/219_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/533_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/030_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/367-4.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/DT/367-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/677-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/607_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/542-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/533_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/533_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/128-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/576_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/909-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/120-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/285_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/964-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/136-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/443-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/713_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/136-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/482-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/413_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/607_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/128-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/157_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/880_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/128-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/663_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/958-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/157_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/DT/542-1.jpg
# ...
# Formatting Image: /content/drive/My Drive/All_Images/HP/030_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HP/576_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HP/120-6.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HP/903-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HP/136-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HP/413_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/746_3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/HS/746_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/309-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/548_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/954-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/309-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/136-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/142 (4).jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/746_2.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/HS/746_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/128-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/120-6.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/367-3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/HS/367-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/713_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/663_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/713_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/250_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/548_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/836_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/746_5.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/HS/746_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/837_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/542-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/img_20191120_151132.jpg
# Formatting Image: /content/drive/My Drive/All_Images/HS/836_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/482-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/142 (1).jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/182_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/373-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/219_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/533_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/954-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/533_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/373-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/606_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/081_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/081_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/309-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/576_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/136-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/576_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/309-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/746_5.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/LB/746_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/219_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/964-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/663_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/LB/959-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/030_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/219_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/542-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/606_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/373-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/607_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/880_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/142 (4).jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/600-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/516_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/958-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/413_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/836_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/954-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/181_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/153_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/663_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/413_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/136-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/903-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/142 (2).jpg
# Formatting Image: /content/drive/My Drive/All_Images/MC/367-3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/MC/367-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/250_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/677-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/600-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/576_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/142 (5).jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/157_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/153_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/903-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/030_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/837_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/219_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/182_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/713_7.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/713_9.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/219_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/964-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/607_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/250_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/954-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/153_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/516_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ME/880_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/548_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/533_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/954-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/219_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/542-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/443-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/250_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/482-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/181_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/964-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/964-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/030_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/153_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/663_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/443-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/128-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/153_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/606_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/905_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/128-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/250_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/ML/746_2.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/ML/746_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/373-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/443-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/905_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/367-4.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/PA/367-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/600-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/836_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/img_20191121_142100.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/285_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/533_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/600-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/954-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/607_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/181_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/713_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/136-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/836_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/309-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/128-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/958-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/542-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/905_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/PA/128-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/903-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/128-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/157_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/153_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/367-1.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/RB/367-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/542-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/677-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/309-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/909-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/182_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/958-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/309-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/373-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/img_20191121_142703.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/142 (5).jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/482-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/081_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/663_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/903-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/413_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/959-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RB/182_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/837_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/443-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/542-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/542-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/081_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/142 (2).jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/182_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/120-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/836_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/030_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/663_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/309-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/482-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/181_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/120-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/367-3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/RO/367-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/219_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/909-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/880_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/120-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/373-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/RO/600-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/576_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/128-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/250_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/219_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/367-3.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/SA/367-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/285_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/905_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/548_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/954-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/482-3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/880_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/954-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/663_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/250_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/157_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/309-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/600-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/713_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/954-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/285_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/964-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/SA/413_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/836_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/128-4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/413_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/482-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/285_3.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/677-2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/746_1.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/TB/746_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/964-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/918-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/367-1.jpg
# Error: Could not open image: /content/drive/My Drive/All_Images/TB/367-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/606_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/516_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/443-5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/607_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/img_20191121_140811.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/413_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/663_5.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/182_1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/909-1.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/030_2.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/250_4.jpg
# Formatting Image: /content/drive/My Drive/All_Images/TB/081_1.jpg

# %%
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input

# Set the training variables
NUM_CLASSES = 16

BATCH_SIZE = 16
EPOCHS = 100

TRAIN_DIR = "train"
TEST_DIR = "test"

# Set a new imput layer with the appropriate shape
inputLayer = Input(shape=(NEW_IMAGE_LENGTH, NEW_IMAGE_HEIGHT, 3))

# Load original model for transfer learning with a new input layer
# NOTE: We are not doing transfer learning fully as we are retraining the full
#       model, but we are still using the layers given by InceptionV3
baseModel = InceptionV3(weights = "imagenet",
                        include_top = False,
                        input_tensor = inputLayer)

# Add new layers for transfer learning
# Add a GlobalAveragePooling2D, Dropout, and Dense layer
x = baseModel.output
x = GlobalAveragePooling2D(name = "avg_pool")(x)
x = Dropout(0.5)(x)
preds = Dense(NUM_CLASSES, activation = "softmax")(x)
model = Model(inputs = baseModel.input, outputs = preds)

# Compile the new model
# Adam optimizer, categorical crossentropy as the loss,
# and accuracy as the metric
model.compile(optimizer = "Adam",
              loss = "categorical_crossentropy",
              metrics = ["accuracy"])

def createImageDataGenerator():
  """
  createImageDataGenerator

  Creates a new ImageDataGenerator and returns the created generator.

  @input  None

  @return The created generator
  """
  generator = ImageDataGenerator(preprocessing_function = preprocess_input,
                                 shear_range = 0.2, # Displace each point proportionally to simulate pictures of different proportions of buildings
                                 zoom_range = 0.2, # Zoom range to simulate taking pictures from different distances
                                 horizontal_flip = True, # Look from different angle
                                 width_shift_range = 0.2, # Simulate different proportions of a building
                                 height_shift_range = 0.2, # Simulate different proportions of a buildings
                                 rotation_range = 15, # Simulate taking pictures while holding camera at an angle
                                 vertical_flip = True, # Some training data images were backwards, so must trian for these situations
                                 fill_mode = 'reflect', # Carleton buildings normally have features repeated
                                 brightness_range = [0.5, 1.5], # Simulate sun/clouds and other weather conditions making image brighter or darker
                                 featurewise_center = True, # Treat each number in array as feature vector
                                 featurewise_std_normalization = True) # Normalization using feature vector
  
  return(generator)

# Create the generators
trainGenerator = createImageDataGenerator()
validationGenerator = createImageDataGenerator()

# Create the datagens using flow and the corresponding data
trainDatagen = trainGenerator.flow(xTrain,
                                   y = yTrain,
                                   batch_size = BATCH_SIZE)

validationDatagen = validationGenerator.flow(xTest,
                                             y = yTest,
                                             batch_size = BATCH_SIZE)

# Fit the generator
history = model.fit_generator(trainGenerator,
                              epochs = EPOCHS,
                              validation_data = validationGenerator)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/100
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 184/184 [==============================] - 209s 1s/step - loss: 2.8109 - acc: 0.0601 - val_loss: 14.3890 - val_acc: 0.0545
# Epoch 2/100
# 184/184 [==============================] - 182s 989ms/step - loss: 2.7668 - acc: 0.0808 - val_loss: 6.8494 - val_acc: 0.0697
# Epoch 3/100
# 184/184 [==============================] - 184s 998ms/step - loss: 2.7866 - acc: 0.0717 - val_loss: 2.7735 - val_acc: 0.0576
# Epoch 4/100
# 184/184 [==============================] - 183s 993ms/step - loss: 2.7779 - acc: 0.0727 - val_loss: 8.3203 - val_acc: 0.0636
# Epoch 5/100
# 184/184 [==============================] - 183s 993ms/step - loss: 2.7642 - acc: 0.0757 - val_loss: 6.3512 - val_acc: 0.0818
# Epoch 6/100
# 184/184 [==============================] - 183s 993ms/step - loss: 2.7726 - acc: 0.0798 - val_loss: 2.7519 - val_acc: 0.0727
# Epoch 7/100
# 184/184 [==============================] - 183s 993ms/step - loss: 2.7912 - acc: 0.0713 - val_loss: 2.8960 - val_acc: 0.0606
# Epoch 8/100
# 184/184 [==============================] - 182s 988ms/step - loss: 2.7636 - acc: 0.0778 - val_loss: 8.1681 - val_acc: 0.0727
# Epoch 9/100
# 184/184 [==============================] - 182s 988ms/step - loss: 2.7326 - acc: 0.0948 - val_loss: 3.3397 - val_acc: 0.0909
# Epoch 10/100
# 184/184 [==============================] - 181s 986ms/step - loss: 2.7074 - acc: 0.1060 - val_loss: 2.8570 - val_acc: 0.0818
# Epoch 11/100
# 184/184 [==============================] - 181s 986ms/step - loss: 2.6932 - acc: 0.1158 - val_loss: 9.3032 - val_acc: 0.0636
# Epoch 12/100
# 184/184 [==============================] - 182s 987ms/step - loss: 2.6279 - acc: 0.1399 - val_loss: 3.9444 - val_acc: 0.0909
# Epoch 13/100
# 184/184 [==============================] - 182s 987ms/step - loss: 2.5016 - acc: 0.1549 - val_loss: 3.5437 - val_acc: 0.1394
# Epoch 14/100
# 184/184 [==============================] - 182s 991ms/step - loss: 2.3952 - acc: 0.1895 - val_loss: 2.6517 - val_acc: 0.2030
# Epoch 15/100
# 184/184 [==============================] - 182s 987ms/step - loss: 2.1839 - acc: 0.2728 - val_loss: 2.4150 - val_acc: 0.2485
# Epoch 16/100
# 184/184 [==============================] - 181s 982ms/step - loss: 2.0674 - acc: 0.3220 - val_loss: 2.2666 - val_acc: 0.3455
# Epoch 17/100
# 184/184 [==============================] - 181s 986ms/step - loss: 1.9521 - acc: 0.3597 - val_loss: 2.1062 - val_acc: 0.3273
# Epoch 18/100
# 184/184 [==============================] - 182s 988ms/step - loss: 1.8406 - acc: 0.3933 - val_loss: 2.1599 - val_acc: 0.3030
# Epoch 19/100
# 184/184 [==============================] - 181s 983ms/step - loss: 1.7558 - acc: 0.4086 - val_loss: 1.8059 - val_acc: 0.4121
# Epoch 20/100
# 184/184 [==============================] - 182s 987ms/step - loss: 1.6541 - acc: 0.4507 - val_loss: 2.7851 - val_acc: 0.3545
# Epoch 21/100
# 184/184 [==============================] - 182s 987ms/step - loss: 1.5486 - acc: 0.4779 - val_loss: 1.8110 - val_acc: 0.4091
# Epoch 22/100
# 184/184 [==============================] - 182s 989ms/step - loss: 1.4777 - acc: 0.5003 - val_loss: 1.6620 - val_acc: 0.4455
# Epoch 23/100
# 184/184 [==============================] - 182s 991ms/step - loss: 1.4472 - acc: 0.5214 - val_loss: 1.8217 - val_acc: 0.4667
# Epoch 24/100
# 184/184 [==============================] - 182s 986ms/step - loss: 1.3128 - acc: 0.5628 - val_loss: 1.4729 - val_acc: 0.4667
# Epoch 25/100
# 184/184 [==============================] - 182s 987ms/step - loss: 1.2924 - acc: 0.5771 - val_loss: 1.4692 - val_acc: 0.5758
# Epoch 26/100
# 184/184 [==============================] - 182s 990ms/step - loss: 1.2403 - acc: 0.5971 - val_loss: 1.5972 - val_acc: 0.5606
# Epoch 27/100
# 184/184 [==============================] - 181s 983ms/step - loss: 1.1393 - acc: 0.6321 - val_loss: 1.6334 - val_acc: 0.5485
# Epoch 28/100
# 184/184 [==============================] - 182s 987ms/step - loss: 1.0434 - acc: 0.6613 - val_loss: 1.7805 - val_acc: 0.5030
# Epoch 29/100
# 184/184 [==============================] - 183s 993ms/step - loss: 1.0330 - acc: 0.6749 - val_loss: 0.9743 - val_acc: 0.7152
# Epoch 30/100
# 184/184 [==============================] - 183s 992ms/step - loss: 0.8934 - acc: 0.7160 - val_loss: 2.5144 - val_acc: 0.5121
# Epoch 31/100
# 184/184 [==============================] - 183s 994ms/step - loss: 0.8573 - acc: 0.7310 - val_loss: 0.9131 - val_acc: 0.7333
# Epoch 32/100
# 184/184 [==============================] - 182s 989ms/step - loss: 0.8072 - acc: 0.7500 - val_loss: 0.9880 - val_acc: 0.6818
# Epoch 33/100
# 184/184 [==============================] - 183s 992ms/step - loss: 0.7667 - acc: 0.7619 - val_loss: 1.0304 - val_acc: 0.7091
# Epoch 34/100
# 184/184 [==============================] - 184s 1s/step - loss: 0.7077 - acc: 0.7853 - val_loss: 0.9083 - val_acc: 0.7424
# Epoch 35/100
# 184/184 [==============================] - 184s 1s/step - loss: 0.6604 - acc: 0.7952 - val_loss: 0.9330 - val_acc: 0.7515
# Epoch 36/100
# 184/184 [==============================] - 184s 1s/step - loss: 0.6371 - acc: 0.8081 - val_loss: 1.0658 - val_acc: 0.7212
# Epoch 37/100
# 184/184 [==============================] - 184s 998ms/step - loss: 0.6073 - acc: 0.8118 - val_loss: 0.9675 - val_acc: 0.7424
# Epoch 38/100
# 184/184 [==============================] - 183s 995ms/step - loss: 0.5785 - acc: 0.8251 - val_loss: 1.1292 - val_acc: 0.6545
# Epoch 39/100
# 184/184 [==============================] - 182s 989ms/step - loss: 0.6283 - acc: 0.8064 - val_loss: 0.6568 - val_acc: 0.7939
# Epoch 40/100
# 184/184 [==============================] - 183s 992ms/step - loss: 0.5499 - acc: 0.8291 - val_loss: 0.6077 - val_acc: 0.7848
# Epoch 41/100
# 184/184 [==============================] - 183s 997ms/step - loss: 0.4991 - acc: 0.8478 - val_loss: 0.7391 - val_acc: 0.7818
# Epoch 42/100
# 184/184 [==============================] - 183s 996ms/step - loss: 0.5025 - acc: 0.8516 - val_loss: 0.6116 - val_acc: 0.8636
# Epoch 43/100
# 184/184 [==============================] - 184s 998ms/step - loss: 0.4690 - acc: 0.8580 - val_loss: 0.9496 - val_acc: 0.7515
# Epoch 44/100
# 184/184 [==============================] - 183s 997ms/step - loss: 0.4655 - acc: 0.8546 - val_loss: 0.8290 - val_acc: 0.8091
# Epoch 45/100
# 184/184 [==============================] - 184s 998ms/step - loss: 0.4177 - acc: 0.8804 - val_loss: 0.5495 - val_acc: 0.8515
# Epoch 46/100
# 184/184 [==============================] - 184s 1s/step - loss: 0.4310 - acc: 0.8733 - val_loss: 0.6409 - val_acc: 0.8394
# Epoch 47/100
# 184/184 [==============================] - 183s 993ms/step - loss: 0.4258 - acc: 0.8651 - val_loss: 0.6893 - val_acc: 0.8394
# Epoch 48/100
# 184/184 [==============================] - 182s 992ms/step - loss: 0.4162 - acc: 0.8750 - val_loss: 0.4816 - val_acc: 0.8667
# Epoch 49/100
# 184/184 [==============================] - 183s 992ms/step - loss: 0.3845 - acc: 0.8886 - val_loss: 0.6704 - val_acc: 0.8242
# Epoch 50/100
# 184/184 [==============================] - 183s 992ms/step - loss: 0.3644 - acc: 0.8944 - val_loss: 0.4623 - val_acc: 0.8939
# Epoch 51/100
# 184/184 [==============================] - 182s 991ms/step - loss: 0.3731 - acc: 0.8896 - val_loss: 0.5473 - val_acc: 0.8727
# Epoch 52/100
# 184/184 [==============================] - 182s 990ms/step - loss: 0.3332 - acc: 0.8950 - val_loss: 0.5203 - val_acc: 0.8758
# Epoch 53/100
# 184/184 [==============================] - 181s 983ms/step - loss: 0.3577 - acc: 0.8899 - val_loss: 0.8282 - val_acc: 0.8000
# Epoch 54/100
# 184/184 [==============================] - 181s 985ms/step - loss: 0.3338 - acc: 0.9032 - val_loss: 0.6328 - val_acc: 0.8424
# Epoch 55/100
# 184/184 [==============================] - 180s 979ms/step - loss: 0.3140 - acc: 0.8995 - val_loss: 0.7359 - val_acc: 0.8242
# Epoch 56/100
# 184/184 [==============================] - 181s 986ms/step - loss: 0.3545 - acc: 0.8923 - val_loss: 0.5523 - val_acc: 0.8606
# Epoch 57/100
# 184/184 [==============================] - 181s 983ms/step - loss: 0.3119 - acc: 0.9107 - val_loss: 0.8277 - val_acc: 0.7758
# Epoch 58/100
# 184/184 [==============================] - 181s 986ms/step - loss: 0.2888 - acc: 0.9100 - val_loss: 0.4119 - val_acc: 0.9000
# Epoch 59/100
# 184/184 [==============================] - 181s 983ms/step - loss: 0.2707 - acc: 0.9188 - val_loss: 0.6703 - val_acc: 0.8152
# Epoch 60/100
# 184/184 [==============================] - 181s 984ms/step - loss: 0.2865 - acc: 0.9110 - val_loss: 0.7276 - val_acc: 0.8182
# Epoch 61/100
# 184/184 [==============================] - 181s 983ms/step - loss: 0.2587 - acc: 0.9232 - val_loss: 0.5527 - val_acc: 0.8788
# Epoch 62/100
# 184/184 [==============================] - 179s 974ms/step - loss: 0.2649 - acc: 0.9164 - val_loss: 0.5705 - val_acc: 0.8667
# Epoch 63/100
# 184/184 [==============================] - 180s 978ms/step - loss: 0.2810 - acc: 0.9151 - val_loss: 0.5276 - val_acc: 0.8485
# Epoch 64/100
# 184/184 [==============================] - 180s 976ms/step - loss: 0.2770 - acc: 0.9134 - val_loss: 0.5364 - val_acc: 0.8818
# Epoch 65/100
# 184/184 [==============================] - 184s 1s/step - loss: 0.2630 - acc: 0.9219 - val_loss: 0.4962 - val_acc: 0.8939
# Epoch 66/100
# 184/184 [==============================] - 182s 992ms/step - loss: 0.2486 - acc: 0.9226 - val_loss: 0.4268 - val_acc: 0.8667
# Epoch 67/100
# 184/184 [==============================] - 184s 998ms/step - loss: 0.2290 - acc: 0.9304 - val_loss: 0.4000 - val_acc: 0.8939
# Epoch 68/100
# 184/184 [==============================] - 184s 1s/step - loss: 0.2415 - acc: 0.9260 - val_loss: 0.5910 - val_acc: 0.8788
# Epoch 69/100
# 184/184 [==============================] - 182s 987ms/step - loss: 0.2329 - acc: 0.9266 - val_loss: 0.5225 - val_acc: 0.8364
# Epoch 70/100
# 184/184 [==============================] - 184s 1000ms/step - loss: 0.2225 - acc: 0.9365 - val_loss: 0.5052 - val_acc: 0.8788
# Epoch 71/100
# 184/184 [==============================] - 183s 995ms/step - loss: 0.2746 - acc: 0.9253 - val_loss: 0.6144 - val_acc: 0.8485
# Epoch 72/100
# 184/184 [==============================] - 184s 1000ms/step - loss: 0.2283 - acc: 0.9283 - val_loss: 0.4051 - val_acc: 0.8879
# Epoch 73/100
# 184/184 [==============================] - 182s 992ms/step - loss: 0.2271 - acc: 0.9334 - val_loss: 0.3679 - val_acc: 0.9303
# Epoch 74/100
# 184/184 [==============================] - 184s 998ms/step - loss: 0.1900 - acc: 0.9477 - val_loss: 0.3241 - val_acc: 0.9121
# Epoch 75/100
# 184/184 [==============================] - 186s 1s/step - loss: 0.2138 - acc: 0.9317 - val_loss: 0.3826 - val_acc: 0.9242
# Epoch 76/100
# 184/184 [==============================] - 186s 1s/step - loss: 0.1995 - acc: 0.9361 - val_loss: 0.5449 - val_acc: 0.8788
# Epoch 77/100
# 184/184 [==============================] - 186s 1s/step - loss: 0.1892 - acc: 0.9416 - val_loss: 0.4574 - val_acc: 0.8818
# Epoch 78/100
# 184/184 [==============================] - 186s 1s/step - loss: 0.1894 - acc: 0.9426 - val_loss: 0.3258 - val_acc: 0.9273
# Epoch 79/100
# 184/184 [==============================] - 185s 1s/step - loss: 0.2358 - acc: 0.9297 - val_loss: 0.4327 - val_acc: 0.8909
# Epoch 80/100
# 184/184 [==============================] - 185s 1s/step - loss: 0.1854 - acc: 0.9436 - val_loss: 0.6372 - val_acc: 0.8576
# Epoch 81/100
# 184/184 [==============================] - 184s 1s/step - loss: 0.1852 - acc: 0.9399 - val_loss: 0.4381 - val_acc: 0.9303
# Epoch 82/100
# 184/184 [==============================] - 185s 1s/step - loss: 0.1917 - acc: 0.9378 - val_loss: 1.4170 - val_acc: 0.7091
# Epoch 83/100
# 184/184 [==============================] - 183s 997ms/step - loss: 0.1756 - acc: 0.9446 - val_loss: 0.5620 - val_acc: 0.8939
# Epoch 84/100
# 184/184 [==============================] - 179s 972ms/step - loss: 0.1825 - acc: 0.9429 - val_loss: 0.4469 - val_acc: 0.8970
# Epoch 85/100
# 184/184 [==============================] - 178s 969ms/step - loss: 0.1953 - acc: 0.9436 - val_loss: 0.4120 - val_acc: 0.9303
# Epoch 86/100
# 184/184 [==============================] - 177s 963ms/step - loss: 0.1713 - acc: 0.9504 - val_loss: 0.4148 - val_acc: 0.8788
# Epoch 87/100
# 184/184 [==============================] - 178s 967ms/step - loss: 0.1689 - acc: 0.9490 - val_loss: 0.3674 - val_acc: 0.9242
# Epoch 88/100
# 184/184 [==============================] - 178s 967ms/step - loss: 0.1878 - acc: 0.9487 - val_loss: 0.6591 - val_acc: 0.8485
# Epoch 89/100
# 184/184 [==============================] - 179s 971ms/step - loss: 0.1742 - acc: 0.9463 - val_loss: 0.4900 - val_acc: 0.8939
# Epoch 90/100
# 184/184 [==============================] - 179s 973ms/step - loss: 0.1552 - acc: 0.9579 - val_loss: 0.3665 - val_acc: 0.9152
# Epoch 91/100
# 184/184 [==============================] - 178s 970ms/step - loss: 0.1536 - acc: 0.9538 - val_loss: 0.3730 - val_acc: 0.9121
# Epoch 92/100
# 184/184 [==============================] - 179s 975ms/step - loss: 0.1467 - acc: 0.9582 - val_loss: 0.4415 - val_acc: 0.8939
# Epoch 93/100
# 184/184 [==============================] - 179s 974ms/step - loss: 0.1574 - acc: 0.9545 - val_loss: 0.4795 - val_acc: 0.9030
# Epoch 94/100
# 184/184 [==============================] - 180s 976ms/step - loss: 0.1690 - acc: 0.9507 - val_loss: 0.4243 - val_acc: 0.9182
# Epoch 95/100
# 184/184 [==============================] - 179s 975ms/step - loss: 0.1368 - acc: 0.9586 - val_loss: 0.4051 - val_acc: 0.8939
# Epoch 96/100
# 184/184 [==============================] - 180s 976ms/step - loss: 0.1645 - acc: 0.9521 - val_loss: 0.4306 - val_acc: 0.8970
# Epoch 97/100
# 184/184 [==============================] - 180s 976ms/step - loss: 0.1523 - acc: 0.9524 - val_loss: 0.3480 - val_acc: 0.9121
# Epoch 98/100
# 184/184 [==============================] - 179s 971ms/step - loss: 0.1170 - acc: 0.9660 - val_loss: 0.7046 - val_acc: 0.8394
# Epoch 99/100
# 184/184 [==============================] - 179s 972ms/step - loss: 0.1590 - acc: 0.9504 - val_loss: 0.3636 - val_acc: 0.8970
# Epoch 100/100
# 184/184 [==============================] - 179s 974ms/step - loss: 0.1526 - acc: 0.9545 - val_loss: 0.4277 - val_acc: 0.9152

# %%
def getMaxIndInList(listToParse):
  """
  Returns the index with the maximum value in the given list.

  @input  listToParse The list to check

  @return The index with the highest value
  """
  return(listToParse.index(max(listToParse)))

# Preprocess the test (holdout) set
x = xTest
x = preprocess_input(x)

# Predict all of the values in the test set
preds = model.predict(x)

# Initialuze the variables used to keep track of the correct count
# and the incorrect predictions
count = 0
matches = {}
for code in BUILDING_CODES:
  matches[code] = {}
  matches[code]["CORRECT"] = 0
  matches[code]["INCORRECT"] = {}
  for code2 in BUILDING_CODES:
    if code != code2:
      matches[code]["INCORRECT"][code2] = 0

# Loop through all of the predictions to check if they are correct
# and if incorrect, mark down what the incorrect value was
for i in range(len(preds)):
  # To get the prediction:
  #   For both the prediction and actual value:
  #     Covert the values to a list
  #     Get the maximum indices in the lists
  #     Get the final codes
  pred = preds[i].tolist()
  actual = yTest[i].tolist()

  predInd = getMaxIndInList(pred)
  actualInd = getMaxIndInList(actual)
  
  actualCode = BUILDING_CODES[actualInd]
  predCode = BUILDING_CODES[predInd]

  # Check if the indices match and iterate the corresponding values
  if (predInd == actualInd):
    matches[actualCode]["CORRECT"] += 1
    count += 1
  else:
    matches[actualCode]["INCORRECT"][predCode] += 1

# Print out the final information
maxCount = len(preds)
print("Result: %d/%d = %f" % (count, maxCount, count / maxCount))
for code in matches:
  print("Building Code: %s, Correct: %d" % (code, matches[code]["CORRECT"]))
  print("\tIncorrect predictions:")
  incorrect = matches[code]["INCORRECT"]
  for code2 in incorrect:
    if incorrect[code2] > 0:
      print("\t\tBuilding Code: %s, Times Mismatched: %d" % (code2, incorrect[code2]))
# Out:
# Result: 308/330 = 0.933333
# Building Code: AA, Correct: 20
# 	Incorrect predictions:
# Building Code: CB, Correct: 22
# 	Incorrect predictions:
# Building Code: CT, Correct: 20
# 	Incorrect predictions:
# 		Building Code: CB, Times Mismatched: 1
# Building Code: DT, Correct: 21
# 	Incorrect predictions:
# 		Building Code: MC, Times Mismatched: 1
# Building Code: FH, Correct: 17
# 	Incorrect predictions:
# 		Building Code: TB, Times Mismatched: 1
# Building Code: HP, Correct: 18
# 	Incorrect predictions:
# 		Building Code: AA, Times Mismatched: 1
# 		Building Code: FH, Times Mismatched: 1
# Building Code: HS, Correct: 15
# 	Incorrect predictions:
# 		Building Code: CB, Times Mismatched: 3
# Building Code: LB, Correct: 21
# 	Incorrect predictions:
# Building Code: MC, Correct: 18
# 	Incorrect predictions:
# 		Building Code: LB, Times Mismatched: 2
# 		Building Code: SA, Times Mismatched: 1
# Building Code: ME, Correct: 22
# 	Incorrect predictions:
# Building Code: ML, Correct: 16
# 	Incorrect predictions:
# 		Building Code: CB, Times Mismatched: 2
# 		Building Code: RO, Times Mismatched: 1
# 		Building Code: TB, Times Mismatched: 2
# Building Code: PA, Correct: 21
# 	Incorrect predictions:
# Building Code: RB, Correct: 21
# 	Incorrect predictions:
# Building Code: RO, Correct: 19
# 	Incorrect predictions:
# 		Building Code: CT, Times Mismatched: 2
# Building Code: SA, Correct: 20
# 	Incorrect predictions:
# 		Building Code: CB, Times Mismatched: 1
# Building Code: TB, Correct: 17
# 	Incorrect predictions:
# 		Building Code: CB, Times Mismatched: 1
# 		Building Code: CT, Times Mismatched: 1
# 		Building Code: ML, Times Mismatched: 1

# %% [markdown]
# ##Step N: Save the model to file

# %%
# Whatever code is required to save your trained model to a file. 
# Should be re-loaded by prepareModel() during testing.
MODEL_FILE = "filename.model"

model.save(MODEL_FILE)
